# %%
import sys
sys.path.append('../scripts')
from robot import *

m = Map()
m.append_landmark(Landmark(1,0))

distance = []
direction = []

for i in range(1000):
    c = Camera(m)
    d = c.data(np.array([0.0,0.0,0.0]).T)
    if  len(d) > 0:
        distance.append(d[0][0][0])
        direction.append(d[0][0][1])

import pandas as pd
df = pd.DataFrame()
df["distance"] = distance
df["direction"] = direction
df
# Out:
#      distance  direction
# 0    1.066680  -0.000386
# 1    0.843983   0.000840
# 2    1.078343   0.100953
# 3    1.046773  -0.021045
# 4    1.120725  -0.020747
# ..        ...        ...
# 889  0.928798  -0.003937
# 890  1.165006   0.032945
# 891  1.118636   0.041508
# 892  1.062287   0.023698
# 893  1.262622   0.010249
#
# [894 rows x 2 columns]

# %%
df.std()
# Out:
# distance     0.141056
# direction    0.047621
# dtype: float64

# %%
df.mean()
# Out:
# distance     1.002841
# direction   -0.000692
# dtype: float64
