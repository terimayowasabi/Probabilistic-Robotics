# %%
import sys
sys.path.append('../scripts')
from robot import *

m = Map()
m.append_landmark(Landmark(1,0))

distance = []
direction = []

for i in range(1000):
    c = Camera(m)
    d = c.data(np.array(0.0,0.0][0]).T)
    if  len(d) > 0:
        distace.append(d[0][0][0])
        direction.append(d[0][0][1])

import pandas as pd
df = pd.DataFrame()
df["distance"] = distance
df["direction"] = direction
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      11 for i in range(1000):
#      12     c = Camera(m)
# ---> 13     d = c.data(np.array(d[0][0][0]).T)
#      14     if  len(d) > 0:
#      15         distace.append(d[0][0][0])
#
# NameError: name 'd' is not defined

# %%
df.
